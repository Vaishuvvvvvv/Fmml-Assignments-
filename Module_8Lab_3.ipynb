# %% [markdown]
# <a href="https://colab.research.google.com/github/Vaishuvvvvvv/Fmml-Assignments-/blob/main/Module_8Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-05-07 09:53:08--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   273MB/s    in 0.3s
#
# 2023-05-07 09:53:11 (273 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 20115   1410.2056v1  In this paper, an improved multimodal optimiza...    cs
# 9050    1411.5726v2  Automatically describing an image with a sente...    cs
# 11520  1605.05775v2  Tensor networks are efficient representations ...  stat
# 23704   1101.2243v1  A symmetrical model of color vision, the decod...    cs
# 13039   1310.4210v2  We propose a novel method for clustering data ...    cs
# ...             ...                                                ...   ...
# 5371    1306.0940v5  Most provably-efficient learning algorithms in...  stat
# 13064   1411.3787v1  Minwise hashing (Minhash) is a widely popular ...  stat
# 8693   1712.01655v3  The point of this paper is to question typical...    cs
# 11688  1609.09196v1  Thanks to the rise of wearable and connected d...  stat
# 5098    1306.1653v1  The Liouville theorem states that bounded holo...    cs
#
#                                                    title  year  \
# 20115  An improved multimodal PSO method based on ele...  2014
# 9050   CIDEr: Consensus-based Image Description Evalu...  2014
# 11520  Supervised Learning with Quantum-Inspired Tens...  2016
# 23704  Illustrating Color Evolution and Color Blindne...  2010
# 13039      Demystifying Information-Theoretic Clustering  2013
# ...                                                  ...   ...
# 5371   (More) Efficient Reinforcement Learning via Po...  2013
# 13064                         Asymmetric Minwise Hashing  2014
# 8693              A Pitfall of Unsupervised Pre-Training  2017
# 11688  EXTRACT: Strong Examples from Weakly-Labeled S...  2016
# 5098   Non-constant bounded holomorphic functions of ...  2013
#
#                                                 keywords
# 20115  [multimodal, optimization, algorithmcalled, ls...
# 9050   [automatically, describing, challenge, process...
# 11520  [efficient, representations, dimensional, succ...
# 23704  [symmetrical, introduced, continuous, numerica...
# 13039  [clustering, information, theoretic, principle...
# ...                                                  ...
# 5371   [efficient, algorithms, introduce, understood,...
# 13064  [estimating, resemblance, suboptimal, applicat...
# 8693   [assumptions, alternatives, particular, contri...
# 11688  [connected, generated, unfortunately, extracti...
# 5098   [liouville, holomorphic, functions, necessaril...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 20115    [multimodal, optimization, algorithmcalled, ls...
# 9050     [automatically, describing, challenge, process...
# 11520    [efficient, representations, dimensional, succ...
# 23704    [symmetrical, introduced, continuous, numerica...
# 13039    [clustering, information, theoretic, principle...
#                                ...
# 15367    [translation, processing, currently, statistic...
# 3727     [adjusting, stochastic, important, unresolved,...
# 26109    [trajectory, simplification, encountered, prog...
# 14955    [recognition, handcrafted, independent, automa...
# 10819    [restricted, successfully, recommender, collab...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8732 words.
# Out of those 4533 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="0770e669-7583-4695-95b8-39ff9142af73" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0770e669-7583-4695-95b8-39ff9142af73")) {                    Plotly.newPlot(                        "0770e669-7583-4695-95b8-39ff9142af73",                        [{"x":["benchmark","optimization","algorithm","interaction","demonstrated","algorithms","alternative","prevented","performed","outperform","attenuation","neighbours","neighbour","modification","multimodal","functions","following","particles","classification","challenging","benchmarking","sentences","automated","evaluation","comparisons","attribute","automatically","evaluating","processing","describing","systematic","available","recognition","detection","descriptions","annotations","consensus","generated","challenge","collecting","description","approaches","parameterize","structure","optimizing","additional","applications","supervised","classifying","efficient","representations","mathematics","demonstrate","generative","successful","interpretation","dimensional","according","blindness","numerical","evolution","illustrated","physiological","illustrating","identical","naturally","concisely","continuous","transform","introduced","symmetrical","discussed","advantages","intuition","maximizing","axiomatic","fundamental","foundations","performance","clustering","meaningful","deteriorate","principles","consistency","parametric","theoretic","assumption","demystifying","increases","assumptions","conceptual","information","representation","transformation","unchanged","translating","invariant","factorization","improving","application","extensions","deviations","magnitude","embeddings","interpretable","convergence","quadratic","markovian","embedding","simultaneously","occurrence","properties","increasing","investigate","preliminary","stopwords","influence","shortening","reflected","coefficient","establish","subsequent","linguistic","systematically","restricted","different","treatments","introduces","segmentation","probability","independent","background","subtraction","exponentially","formulates","framework","outperforms","estimated","extensive","sequences","filtering","multilayer","platforms","appearance","foreground","capability","similarity","advantage","methodologies","previously","attention","automatic","variations","annotated","computational","comparison","bioinformatics","specifically","similarities","considering","determining","possesses","constraints","biological","processes","investigated","validation","annotation","organisms","precisely","understand","programming","significant","probabilities","optimizations","contingent","arbitrary","especially","languages","incorporates","efficiently","comparing","inference","describes","dependencies","management","probabilistic","posterior","experiments","structures","eliminate","publication","relationships","representing","effective","recommendation","particularly","discovering","important","publicity"],"y":[200,299,777,95,103,584,100,4,152,101,6,3,8,25,32,214,94,11,545,273,12,60,120,255,26,33,187,55,282,30,40,291,360,339,33,52,17,168,162,12,84,437,4,335,33,109,432,214,37,386,231,9,534,114,76,64,180,103,4,73,61,18,9,6,16,60,4,115,62,150,2,51,83,28,33,10,93,8,892,148,41,5,27,49,38,35,59,3,51,71,31,690,386,66,2,18,63,39,103,237,49,9,48,66,33,120,22,7,104,95,31,198,103,121,57,4,58,2,5,34,47,23,66,14,38,740,3,91,209,181,136,77,7,21,3,565,245,51,177,89,59,10,30,69,22,64,147,94,15,89,183,185,70,72,266,141,10,169,36,78,38,11,145,50,109,47,52,63,5,32,72,106,252,71,8,1,87,112,100,33,144,90,202,98,59,52,153,36,596,122,18,11,66,72,237,22,82,25,350,2],"type":"bar"},{"x":["benchmark","optimization","algorithm","interaction","demonstrated","algorithms","alternative","pre ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4533,), (4533, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7933333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Fair</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Clustering</span> <span style=''>Through</span> <span style=''>Fairlets</span> <br/><br/><span style=''>We</span> <span style=''>study</span> <span style=''>the</span> <span style=''>question</span> <span style=''>of</span> <span style=''>fair</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>clustering</span> <span style=''>under</span> <span style=''>the</span> <span style=''>em</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>disparate</span> <span style=''>impact</span> <span style=''>doctrine</span> <span style=''>where</span> <span style=''>each</span> <span style='background-color:rgba(255, 0, 0, 0.33333333333333337);'>protected</span> <span style=''>class</span> <span style=''>must</span> <span style=''>have</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximately</span> <span style=''>equal</span> <span style='background-color:rgba(0, 255, 0, 0.40619307832422596);'>representation</span> <span style=''>in</span> <span style=''>every</span> <span style=''>cluster</span> <span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>formulate</span> <span style=''>the</span> <span style=''>fair</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>clustering</span> <span style=''>problem</span> <span style=''>under</span> <span style=''>both</span> <span style=''>the</span> <span style=''>k</span> <span style=''>center</span> <span style=''>and</span> <span style=''>the</span> <span style=''>k</span> <span style=''>median</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>objectives</span> <span style=''>and</span> <span style=''>show</span> <span style=''>that</span> <span style=''>even</span> <span style=''>with</span> <span style=''>two</span> <span style='background-color:rgba(255, 0, 0, 0.33333333333333337);'>protected</span> <span style=''>classes</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.40359897172236514);'>challenging</span> <span style=''>as</span> <span style=''>the</span> <span style=''>optimum</span> <span style=''>solution</span> <span style=''>can</span> <span style=''>violate</span> <span style=''>common</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>conventions</span> <span style=''>for</span> <span style=''>instance</span> <span style=''>a</span> <span style=''>point</span> <span style=''>may</span> <span style=''>no</span> <span style=''>longer</span> <span style=''>be</span> <span style=''>assigned</span> <span style=''>to</span> <span style=''>its</span> <span style=''>nearest</span> <span style=''>cluster</span> <span style=''>center</span> <span style=''>En</span> <span style=''>route</span> <span style=''>we</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduce</span> <span style=''>the</span> <span style=''>concept</span> <span style=''>of</span> <span style=''>fairlets</span> <span style=''>which</span> <span style=''>are</span> <span style=''>minimal</span> <span style=''>sets</span> <span style=''>that</span> <span style=''>satisfy</span> <span style=''>fair</span> <span style='background-color:rgba(0, 255, 0, 0.40619307832422596);'>representation</span> <span style=''>while</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximately</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>preserving</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>clustering</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>objective</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>any</span> <span style=''>fair</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>clustering</span> <span style=''>problem</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>decompose ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Semisupervised</span> <span style=''>Learning</span> <span style=''>with</span> <span style=''>Deep</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Generative</span> <span style=''>Models</span> <br/><br/><span style=''>Neural</span> <span style=''>network</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generative</span> <span style=''>models</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>discriminative</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>components</span> <span style=''>are</span> <span style=''>a</span> <span style=''>powerful</span> <span style=''>approach</span> <span style=''>for</span> <span style=''>semi</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>supervised</span> <span style=''>learning</span> <span style=''>However</span> <span style=''>these</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>techniques</span> <span style=''>a)</span> <span style=''>cannot</span> <span style=''>account</span> <span style=''>for</span> <span style=''>model</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>uncertainty</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style=''>of</span> <span style=''>the</span> <span style=''>models</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>discriminative</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>component</span> <span style=''>and</span> <span style=''>b)</span> <span style=''>lack</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>flexibility</span> <span style=''>to</span> <span style=''>capture</span> <span style=''>complex</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style=''>patterns</span> <span style=''>in</span> <span style=''>the</span> <span style=''>label</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generation</span> <span style=''>process</span> <span style=''>To</span> <span style=''>avoid</span> <span style=''>these</span> <span style=''>problems</span> <span style=''>we</span> <span style=''>first</span> <span style=''>propose</span> <span style=''>to</span> <span style=''>use</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>discriminative</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>component</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style=''>inputs</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>increased</span> <span style=''>noise</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>flexibility</span> <span style=''>We</span> <span style=''>show</span> <span style=''>how</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficient</span> <span style=''>Gibbs</span> <span style=''>sampling</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>procedure</span> <span style=''>can</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>marginalize</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style=''>inputs</span> <span style=''>when</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inferring</span> <span style=''>missing</span> <span style=''>labels</span> <span style=''>in</span> <span style=''>this</span> <span style=''>model</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Following</span> <span style=''>this</span> <span style=''>we</span> <span style=''>extend</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>discriminative</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>component</span> <span style=''>to</span> <span style=''>be</spa ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Matrix</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Completion</span> <span style=''>and</span> <span style=''>Related</span> <span style=''>Problems</span> <span style=''>via</span> <span style=''>Strong</span> <span style=''>Duality</span> <br/><br/><span style=''>This</span> <span style=''>work</span> <span style=''>studies</span> <span style=''>the</span> <span style=''>strong</span> <span style=''>duality</span> <span style=''>of</span> <span style=''>non</span> <span style=''>convex</span> <span style=''>matrix</span> <span style='background-color:rgba(255, 0, 0, 0.3217391304347825);'>factorization</span> <span style=''>problems</span> <span style=''>we</span> <span style=''>show</span> <span style=''>that</span> <span style=''>under</span> <span style=''>certain</span> <span style=''>dual</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditions</span> <span style=''>these</span> <span style=''>problems</span> <span style=''>and</span> <span style=''>its</span> <span style=''>dual</span> <span style=''>have</span> <span style=''>the</span> <span style=''>same</span> <span style=''>optimum</span> <span style=''>This</span> <span style=''>has</span> <span style=''>been</span> <span style=''>well</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>understood</span> <span style=''>for</span> <span style=''>convex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>but</span> <span style=''>little</span> <span style=''>was</span> <span style=''>known</span> <span style=''>for</span> <span style=''>non</span> <span style=''>convex</span> <span style=''>problems</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>novel</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>analytical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>and</span> <span style=''>show</span> <span style=''>that</span> <span style=''>under</span> <span style=''>certain</span> <span style=''>dual</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditions</span> <span style=''>the</span> <span style=''>optimal</span> <span style=''>solution</span> <span style=''>of</span> <span style=''>the</span> <span style=''>matrix</span> <span style='background-color:rgba(255, 0, 0, 0.3217391304347825);'>factorization</span> <span style=''>program</span> <span style=''>is</span> <span style=''>the</span> <span style=''>same</span> <span style=''>as</span> <span style=''>its</span> <span style=''>bi</span> <span style=''>dual</span> <span style=''>and</span> <span style=''>thus</span> <span style=''>the</span> <span style=''>global</span> <span style='background-color:rgba(255, 0, 0, 0.3454545454545454);'>optimality</span> <span style=''>of</span> <span style=''>the</span> <span style=''>non</span> <span style=''>convex</span> <span style=''>program</span> <span style=''>can</span> <span style=''>be</span> <span style=''>achieved</span> <span style=''>by</span> <span style=''>solving</span> <span style=''>its</span> <span style=''>bi</span> <span style=''>dual</span> <span style=''>which</span> <span style=''>is</span> <span style=''>convex</span> <span style=''>These</span> <span style=''>dual</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditions</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>satisfied</span> <span style=''>by</span> <span style=''>a</span> <span style=''>wide</span> <span style=''>class</span> <span style=''>of</span> <span style=''>matrix</span> <span style='background-color:rgba(255, 0, 0, 0.3217391304347825);'>factorization</span> <span style=''>problems</span> <span style=''>although</span> <span style=''>matrix</span> <span style='background-color:rgba(255, 0, 0, 0.3217391304347825);'>factorization</span> <span style=''>problems</span> <span style=''>are</span> <span style=''>hard</span> ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>What</span> <span style=''>Does</span> <span style=''>a</span> <span style=''>TextCNN</span> <span style=''>Learn</span> <br/><br/><span style=''>TextCNN</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>convolutional</span> <span style=''>neural</span> <span style=''>network</span> <span style=''>for</span> <span style=''>text</span> <span style=''>is</span> <span style=''>a</span> <span style=''>useful</span> <span style=''>deep</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>for</span> <span style=''>sentence</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>tasks</span> <span style=''>such</span> <span style=''>as</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sentiment</span> <span style=''>analysis</span> <span style=''>and</span> <span style=''>question</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>However</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>have</span> <span style=''>long</span> <span style=''>been</span> <span style=''>known</span> <span style=''>as</span> <span style=''>black</span> <span style=''>boxes</span> <span style=''>because</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interpreting</span> <span style=''>them</span> <span style=''>is</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenging</span> <span style=''>task</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Researchers</span> <span style=''>have</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>developed</span> <span style=''>several</span> <span style=''>tools</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>understand</span> <span style=''>a</span> <span style=''>CNN</span> <span style=''>for</span> <span style=''>image</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>by</span> <span style=''>deep</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>visualization</span> <span style=''>but</span> <span style=''>research</span> <span style=''>about</span> <span style=''>deep</span> <span style=''>TextCNNs</span> <span style=''>is</span> <span style=''>still</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>insufficient</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>are</span> <span style=''>trying</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>understand</span> <span style=''>what</span> <span style=''>a</span> <span style=''>TextCNN</span> <span style=''>learns</span> <span style=''>on</span> <span style=''>two</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classical</span> <span style=''>NLP</span> <span style=''>datasets</span> <span style=''>Our</span> <span style=''>work</span> <span style=''>focuses</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>convolutional</span> <span style=''>kernels</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>correlations</span> <span style=''>between</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>convolutional</span> <span style=''>kernels</span> <br/><br/>

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	experimental (0.13397299218194741)
# 	knowledge (0.1297085998578536)
# 	information (0.24520255863539445)
# 	architecture (0.07995735607675906)
# 	representation (0.13717128642501777)
# 	segmentation (0.07427149964463398)
# 	different (0.26297085998578534)
# 	detection (0.12046908315565032)
# 	recognition (0.1279317697228145)
# 	convolutional (0.13717128642501777)
#
# Some Statistics words are:
# 	stochastic (0.13846928499496475)
# 	theoretical (0.1470292044310171)
# 	variables (0.14350453172205438)
# 	estimation (0.17270896273917422)
# 	statistical (0.16112789526686808)
# 	distribution (0.18580060422960726)
# 	inference (0.18982880161127896)
# 	algorithm (0.39526686807653577)
# 	regression (0.1732124874118832)
# 	dimensional (0.1958710976837865)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="a24bb52e-0cca-4a7b-85d1-183ac5d6a6ba" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a24bb52e-0cca-4a7b-85d1-183ac5d6a6ba")) {                    Plotly.newPlot(                        "a24bb52e-0cca-4a7b-85d1-183ac5d6a6ba",                        [{"x":["benchmark","optimization","algorithm","interaction","demonstrated","algorithms","alternative","prevented","performed","outperform","attenuation","neighbours","neighbour","modification","multimodal","functions","following","particles","classification","challenging","benchmarking","sentences","automated","evaluation","comparisons","attribute","automatically","evaluating","processing","describing","systematic","available","recognition","detection","descriptions","annotations","consensus","generated","challenge","collecting","description","approaches","parameterize","structure","optimizing","additional","applications","supervised","classifying","efficient","representations","mathematics","demonstrate","generative","successful","interpretation","dimensional","according","blindness","numerical","evolution","illustrated","physiological","illustrating","identical","naturally","concisely","continuous","transform","introduced","symmetrical","discussed","advantages","intuition","maximizing","axiomatic","fundamental","foundations","performance","clustering","meaningful","deteriorate","principles","consistency","parametric","theoretic","assumption","demystifying","increases","assumptions","conceptual","information","representation","transformation","unchanged","translating","invariant","factorization","improving","application","extensions","deviations","magnitude","embeddings","interpretable","convergence","quadratic","markovian","embedding","simultaneously","occurrence","properties","increasing","investigate","preliminary","stopwords","influence","shortening","reflected","coefficient","establish","subsequent","linguistic","systematically","restricted","different","treatments","introduces","segmentation","probability","independent","background","subtraction","exponentially","formulates","framework","outperforms","estimated","extensive","sequences","filtering","multilayer","platforms","appearance","foreground","capability","similarity","advantage","methodologies","previously","attention","automatic","variations","annotated","computational","comparison","bioinformatics","specifically","similarities","considering","determining","possesses","constraints","biological","processes","investigated","validation","annotation","organisms","precisely","understand","programming","significant","probabilities","optimizations","contingent","arbitrary","especially","languages","incorporates","efficiently","comparing","inference","describes","dependencies","management","probabilistic","posterior","experiments","structures","eliminate","publication","relationships","representing","effective","recommendation","particularly","discovering","important","publicity","documents","scientific","randomness","presented","publications","disambiguation","wikipedia","differences","ambiguity","typically","necessary","including","classifier","knowledge","statistics","empirical","instances","dictionary","resources","enhancing","synthetic","restrictive","exploiting","additionally","exploitation","statistical","functional","simulations","minimization","statistically","resulting","separation","independence","resonance","parameter","improvement","incorporated","diversity","component","variables","consistent","repository","equivalents","replications","intersecting","bootstrapped","asymptotic","estimation","estimates","regression","selection","regularization","bootstrap","favorably","operators","crossover","premature","intelligent","popu ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	entropies
# 	forecasters
# 	psychiatric
# 	schizophrenia
# 	administrative
# 	quantifiable
# 	sparsifying
# 	collinearity
# 	understandings
# 	duplicate
# 	homogenous
# 	fluctuate
# 	multistep
# 	seasonality
# 	criterions
# 	procrustes
# 	cancellation
# 	subsamples
# 	metabolites
# 	irregularly
# Some words which never appear in Statistics papers:
# 	prevented
# 	attenuation
# 	blindness
# 	axiomatic
# 	deteriorate
# 	stopwords
# 	shortening
# 	publicity
# 	disambiguation
# 	valuation
# 	epistemic
# 	rhetorical
# 	discourse
# 	accordance
# 	argumentation
# 	pheromone
# 	metaheuristic
# 	decidable
# 	translate
# 	reviewers

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.06063110213326e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7533333333333333
